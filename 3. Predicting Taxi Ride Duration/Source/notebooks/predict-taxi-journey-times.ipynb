# %% [markdown]
# # Predict the journey time of taxis in NYC

# %% [markdown]
# Use our pre-trained model for this

# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append('../')

import pandas as pd
import numpy as np
import geopandas
from random import seed, randint
from datetime import datetime

from keras.utils import to_categorical
from model.model import nn
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
model_weights = '../logs/weights-2018-11-21-14-06-29.hdf5'
trip_data_file = '../data/taxi_data/cleansed_yellow_tripdata_2018-06.csv'
weather_data_file = '../data/weather_data/ny_jfk_weather_2018-06.csv'
taxi_zones = '../data/taxi_zones'

# %% [markdown]
# * Load taxi trip data

# %%
tripdata = pd.read_csv(trip_data_file, delimiter=',')

# %%
tripdata.head(10)
# Out:
#    Unnamed: 0  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0           1         1  2018-06-01 00:04:18   2018-06-01 00:09:18
# 1           5         1  2018-06-01 00:09:00   2018-06-01 00:24:01
# 2           6         1  2018-06-01 00:02:33   2018-06-01 00:13:01
# 3           7         1  2018-06-01 00:13:23   2018-06-01 00:16:52
# 4          11         1  2018-06-01 00:39:42   2018-06-01 00:57:23
# 5          12         1  2018-06-01 00:25:43   2018-06-01 00:40:07
# 6          16         2  2018-06-01 00:02:18   2018-06-01 00:08:05
# 7          17         2  2018-06-01 00:40:22   2018-06-01 00:52:20
# 8          18         1  2018-06-01 00:22:51   2018-06-01 00:30:01
# 9          23         1  2018-06-01 00:09:50   2018-06-01 00:20:33
#
#    passenger_count  trip_distance  PULocationID  DOLocationID  tip_amount  \
# 0                1           1.00           230           161        1.35
# 1                1           2.00           161           234        2.55
# 2                2           1.50           163           233        1.95
# 3                1           0.70           186           246        1.85
# 4                1           3.50           141           179        2.95
# 5                1           3.00           138             7        3.45
# 6                1           0.75           229           141        4.00
# 7                1           3.94           148           233        3.70
# 8                1           1.40           142           238        1.75
# 9                1           2.80           231            52        2.15
#
#    total_amount   duration
# 0          8.15   5.000000
# 1         15.35  15.016667
# 2         11.75  10.466667
# 3          8.15   3.483333
# 4         17.75  17.683333
# 5         17.25  14.400000
# 6         10.80   5.783333
# 7         18.50  11.966667
# 8         10.55   7.166667
# 9         13.95  10.716667

# %% [markdown]
# * Load weather data

# %%
weather_data = pd.read_csv(weather_data_file, delimiter=',')

# %%
weather_data.head(10)
# Out:
#    Unnamed: 0        DATE  AWND  PRCP  SNOW  SNWD  TAVG  month
# 0         335  2018-06-01   2.1  30.0   0.0   0.0  19.2      6
# 1         336  2018-06-02   4.5   0.0   0.0   0.0  23.8      6
# 2         337  2018-06-03   7.1   2.8   0.0   0.0  17.1      6
# 3         338  2018-06-04   3.8  15.5   0.0   0.0  13.9      6
# 4         339  2018-06-05   4.4   0.0   0.0   0.0  17.9      6
# 5         340  2018-06-06   3.9   0.0   0.0   0.0  17.2      6
# 6         341  2018-06-07   4.0   0.0   0.0   0.0  15.8      6
# 7         342  2018-06-08   4.2   0.0   0.0   0.0  18.3      6
# 8         343  2018-06-09   2.9   0.0   0.0   0.0  21.6      6
# 9         344  2018-06-10   2.7   0.5   0.0   0.0  20.0      6

# %% [markdown]
# * Load taxizone geo data and convert to degrees based lat/long coordinates

# %%
taxizone_data = geopandas.read_file(taxi_zones).set_index('OBJECTID').to_crs({'init': 'epsg:4326'})
zone_ids = taxizone_data.index.tolist()
taxizone_data['centroids'] = taxizone_data.geometry.centroid.to_crs({'init': 'epsg:4326'})

# %%
taxizone_data.head(10)
# Out:
#           Shape_Leng  Shape_Area                     zone  LocationID  \
# OBJECTID
# 1           0.116357    0.000782           Newark Airport           1
# 2           0.433470    0.004866              Jamaica Bay           2
# 3           0.084341    0.000314  Allerton/Pelham Gardens           3
# 4           0.043567    0.000112            Alphabet City           4
# 5           0.092146    0.000498            Arden Heights           5
# 6           0.150491    0.000606  Arrochar/Fort Wadsworth           6
# 7           0.107417    0.000390                  Astoria           7
# 8           0.027591    0.000027             Astoria Park           8
# 9           0.099784    0.000338               Auburndale           9
# 10          0.099839    0.000436             Baisley Park          10
#
#                 borough                                           geometry  \
# OBJECTID
# 1                   EWR  POLYGON ((-74.18445299999996 40.6949959999999,...
# 2                Queens  (POLYGON ((-73.82337597260663 40.6389870471767...
# 3                 Bronx  POLYGON ((-73.84792614099985 40.87134223399993...
# 4             Manhattan  POLYGON ((-73.97177410965318 40.72582128133706...
# 5         Staten Island  POLYGON ((-74.17421738099989 40.56256808599989...
# 6         Staten Island  POLYGON ((-74.06367318899999 40.60219816599994...
# 7                Queens  POLYGON ((-73.90413637799996 40.76752031699986...
# 8                Queens  POLYGON ((-73.92334041500001 40.77512891199993...
# 9                Queens  POLYGON ((-73.78502434699996 40.76103651599986...
# 10               Queens  POLYGON ((-73.7832662499999 40.68999429299992,...
#
#                                              centroids
# OBJECTID
# 1         POINT (-74.17400027276298 40.69183120640134)
# 2         POINT (-73.83129854302199 40.61674529165965)
# 3         POINT (-73.84742223236724 40.86447368477531)
# 4         POINT (-73.97696825691764 40.72375214158458)
# 5         POINT (-74.18848410184934 40.55265928694552)
# 6          POINT (-74.0717705589514 40.60032414603445)
# 7         POINT (-73.91969431946065 40.76149256216355)
# 8         POINT (-73.92308615750756 40.77855865375055)
# 9         POINT (-73.78794887777896 40.75103502557216)
# 10         POINT (-73.79098635986959 40.6789533101151)

# %% [markdown]
# * Load the pre-trained model

# %%
model = nn(input_shape=68)
model.load_weights(model_weights)
# Out:
# nn(): Creating NN with parameters:
#
# image_shape=68
# output_shape=1
# dropout=0.25
# activation=elu
# optimizer=<keras.optimizers.Adam object at 0x11c2e7e10>
# loss=mean_squared_error

# %% [markdown]
# * Create test data

# %%
test_start_idx = int(len(tripdata) * .8)
test_tripdata = tripdata[test_start_idx:]

# %%
test_tripdata.head(10)
# Out:
#          Unnamed: 0  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 4464536     6963159         2  2018-06-24 20:11:06   2018-06-24 20:22:44
# 4464537     6963160         2  2018-06-24 20:31:46   2018-06-24 20:44:46
# 4464538     6963161         2  2018-06-24 20:48:48   2018-06-24 20:58:53
# 4464539     6963163         2  2018-06-24 20:26:48   2018-06-24 20:38:54
# 4464540     6963164         2  2018-06-24 20:40:36   2018-06-24 20:46:11
# 4464541     6963165         2  2018-06-24 20:10:01   2018-06-24 20:14:57
# 4464542     6963167         2  2018-06-24 20:43:24   2018-06-24 21:30:20
# 4464543     6963169         2  2018-06-24 20:34:55   2018-06-24 20:50:24
# 4464544     6963170         2  2018-06-24 21:00:27   2018-06-24 21:06:16
# 4464545     6963174         2  2018-06-24 20:55:41   2018-06-24 21:09:47
#
#          passenger_count  trip_distance  PULocationID  DOLocationID  \
# 4464536                1           1.73           263           239
# 4464537                1           1.72            48            68
# 4464538                1           1.76            90           163
# 4464539                2           1.94           161            79
# 4464540                1           0.95            79           137
# 4464541                1           1.08           237           236
# 4464542                1           8.98           142           231
# 4464543                2           1.54           100           137
# 4464544                1           0.95           107           137
# 4464545                1           2.84           161           238
#
#          tip_amount  total_amount   duration
# 4464536        2.16         12.96  11.633333
# 4464537        1.00         12.30  13.000000
# 4464538        1.00         11.30  10.083333
# 4464539        2.70         13.50  12.100000
# 4464540        1.46          8.76   5.583333
# 4464541        1.46          8.76   4.933333
# 4464542        1.00         39.30  46.933333
# 4464543        2.46         14.76  15.483333
# 4464544        1.46          8.76   5.816667
# 4464545        3.32         16.62  14.100000

# %% [markdown]
# * Function to map this row of data to fields for our pre-trained model

# %%
def get_features(sample, weather_data, taxizone_data):
    PULocation = taxizone_data.loc[sample['PULocationID']].centroids
    PULocationLong, PULocationLat = PULocation.x, PULocation.y
    DOLocation = taxizone_data.loc[sample['DOLocationID']].centroids
    DOLocationLong, DOLocationLat = DOLocation.x, DOLocation.y

    # Get month date, day of week and hours/mins for pickup
    PUDateTime = datetime.strptime(sample.tpep_pickup_datetime, '%Y-%m-%d %H:%M:%S')
    PUDate = PUDateTime.strftime('%Y-%m-%d')
    PUYear, PUMonth, PUMonthDate = PUDate.split('-')
    # TODO - Add this to pre-processing of trip data! Some random months in the data!!
    if PUYear == '2018' and PUMonth == '06':        
        PUDayOfWeek = PUDateTime.weekday()
        PUTimeHour, PUTimeMinute = datetime.strptime(
            sample.tpep_pickup_datetime, '%Y-%m-%d %H:%M:%S'
        ).strftime('%H:%M').split(':')

        # Get precipitation for that day
        Precipitation = weather_data[weather_data['DATE'] == PUDate]['PRCP'].values[0]

        X = np.concatenate((np.array([

            PULocationLat,
            PULocationLong,
            DOLocationLat,
            DOLocationLong,
            abs((PULocationLat - DOLocationLat) ** 2 + abs(PULocationLong - DOLocationLong) ** 2) ** 0.5,
            Precipitation
        ]),
            to_categorical(PUDayOfWeek, 7),
            to_categorical(PUMonthDate, 31),
            to_categorical(PUTimeHour, 24)
        ))

        y = [sample['duration']]
    else:
        X, y = [], []
    
    return X, y

# %% [markdown]
# * Find a random sample for illustrative purposes
#
# There are over 1million rows in the test set, so let's pick a selection for test purposes

# %%
import pickle
trip_meta = pickle.load(open('../data/taxi_data/yellow_taximeta_2018-06.p', "rb")).set_index('key')

# %%
# seed(42)
num_test_examples = 10
test_index = list(test_tripdata.index)
for i in range(num_test_examples):
    test_example_idx = test_index[randint(0, len(test_tripdata))]
    test_sample = test_tripdata.loc[test_example_idx]
    X, y = get_features(test_sample, weather_data, taxizone_data)
    predicted_duration = model.predict(X.reshape(1,68))
    key = '{:03d}-{:03d}'.format(test_sample['PULocationID'], test_sample['DOLocationID'])
    meta = trip_meta.loc[key]
#     print(meta)
#     print(key)
    print('Sample {} / index {}'.format(i, test_example_idx))
    print('Predicted duration = {}, actual duration = {} '.format(predicted_duration[0][0], y[0]))
    print('min={}, mean={}, max={}'.format(meta['min_trip_time'], meta['mean_trip_time'], meta['max_trip_time']))
    print('')
# Out:
# Sample 0 / index 5415406
# Predicted duration = 13.058308601379395, actual duration = 19.2
# min=11.133333333333333, mean=22.68541666666667, max=78.96666666666667
#
# Sample 1 / index 5229644
# Predicted duration = 13.058308601379395, actual duration = 13.516666666666667
# min=7.183333333333334, mean=15.41338734567902, max=57.45
#
# Sample 2 / index 4805646
# Predicted duration = 13.058308601379395, actual duration = 11.233333333333333
# min=3.5, mean=11.503861326050666, max=47.583333333333336
#
# Sample 3 / index 5240861
# Predicted duration = 13.058308601379395, actual duration = 24.08333333333333
# min=8.233333333333333, mean=23.172362588652504, max=57.666666666666664
#
# Sample 4 / index 5209592
# Predicted duration = 13.058308601379395, actual duration = 7.1
# min=2.9166666666666665, mean=12.44387661141807, max=65.21666666666667
#
# Sample 5 / index 4903904
# Predicted duration = 13.058308601379395, actual duration = 9.2
# min=1.4333333333333333, mean=8.994483938915222, max=48.9
#
# Sample 6 / index 5024429
# Predicted duration = 13.058308601379395, actual duration = 20.266666666666666
# min=10.85, mean=21.85128205128204, max=68.98333333333333
#
# Sample 7 / index 4614277
# Predicted duration = 13.058308601379395, actual duration = 11.666666666666664
# min=2.716666666666667, mean=9.054158169046001, max=38.666666666666664
#
# Sample 8 / index 4823439
# Predicted duration = 13.058308601379395, actual duration = 8.516666666666667
# min=1.6333333333333333, mean=9.23429586563308, max=72.45
#
# Sample 9 / index 4977941
# Predicted duration = 13.058308601379395, actual duration = 6.683333333333334
# min=3.783333333333333, mean=11.301454138702455, max=33.833333333333336
